# %% [markdown]
# # Лабораторная работа №3
# Вариант 2
# ## Индивидуальное задание 1.
# В городе N за последние 10 лет наблюдался рост населения:
# - Годы: [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]
# - Население (тыс. чел.): [50, 52, 55, 58, 60, 63, 67, 70, 73, 75]
#
# Постройте график, обозначьте оси и используйте маркеры на точках.

# %%
import matplotlib.pyplot as plt
import numpy as np
years = [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]
people = [50, 52, 55, 58, 60, 63, 67, 70, 73, 75]
plt.title("Рост населения за последние 10 лет")
plt.xlabel("Годы")
plt.ylabel("Население (тыс. чел.)")
plt.grid()
plt.plot(years, people, marker='o')

# %% [markdown]
# ## Индивидуальное задание 2.
# По итогам экзамена распределение оценок было следующим:
# - Оценки: ['2', '3', '4', '5']
# - Количество студентов: [5, 12, 20, 13]
#
# Постройте горизонтальную столбчатую диаграмму. Добавьте подписи к столбцам.

# %%
marks = ['2', '3', '4', '5']
amount = [5, 12, 20, 13]
plt.xlabel("Оценки")
plt.ylabel("Количество студентов")
plt.title("Оценки студентов")
plt.bar(marks, amount)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ## Индивидуальное задание 3.
# Вычислите площадь под графиком функции:
#
# $f(x) = sin(x)$
#
# на интервале [0, π]. Закрасьте соответствующую область.
#
# Требуется:
# - Построить график подинтегральной функции.
# - Вычислить площадь под кривой на заданном отрезке как значение
# определенного интеграла.
# - Закрасить область под графиком, чтобы визуализировать интеграл.

# %%
a = 0
b = np.pi
x = np.linspace(a, b, 200)
y = np.sin(x)
under = np.trapz(y, x) # рассчет площади под графиком с помощью метода трапеций
print("Площадь под графиком: ", under)
plt.plot(x, y)
plt.fill_between(x, y, where=(y>=0))
# Out:
# Площадь под графиком:  1.9999584621373308

# %% [markdown]
# ## Индивидуальное задание 4.
# Визуализируйте поверхность:
#
# $f(x, y) = x^2 − y^2$
#
# в диапазоне x, y ∈ [−5, 5].
#
# Требуется:
# - Построить трехмерный график функции $f(x, y)$ в заданных пределах.
# - Использовать библиотеку Matplotlib для визуализации.
# - Оформить график: добавить заголовок, подписи осей и цветовую карту (если
# уместно).

# %%
from mpl_toolkits.mplot3d import Axes3D
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
f = X**2 - Y**2
fig = plt.figure()
funct = fig.add_subplot(111, projection='3d')
color_map = funct.plot_surface(X, Y, f, cmap='viridis')
fig.colorbar(color_map, shrink=0.5, aspect=5)
funct.set_title("$f(x, y) = x^2 − y^2$")
funct.set_xlabel('x')
funct.set_ylabel('y')
funct.set_ylabel('z')
# Out:
# Text(0.5, 0.5, 'z')
